# %%
import googlemaps
import re
from pprint import pprint
from dotenv import load_dotenv
import os

# %%
load_dotenv()
gmaps = googlemaps.Client(key=os.environ['GOOGLEAPI_KEY'])

# %%
#取得台北市士林區士東路299巷的地理編碼
geocode_result = gmaps.geocode(address = "台北市中山北路六段")
geocode_result
# Out:
# [{'address_components': [{'long_name': '中山北路六段',
#     'short_name': '中山北路六段',
#     'types': ['route']},
#    {'long_name': 'Shilin District',
#     'short_name': 'Shilin District',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Taipei City',
#     'short_name': 'Taipei City',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Taiwan',
#     'short_name': 'TW',
#     'types': ['country', 'political']},
#    {'long_name': '111', 'short_name': '111', 'types': ['postal_code']}],
#   'formatted_address': '111, Taiwan, Taipei City, Shilin District, 中山北路六段',
#   'geometry': {'bounds': {'northeast': {'lat': 25.1196949, 'lng': 121.531291},
#     'southwest': {'lat': 25.1014665, 'lng': 121.5241541}},
#    'location': {'lat': 25.1105466, 'lng': 121.5255956},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 25.1196949, 'lng': 121.531291},
#     'southwest': {'lat': 25.1014665, 'lng': 121.5241541}}},
#   'place_id': 'ChIJ78cRPIWuQjQR96IbwBTHBBM',
#   'types': ['route']}]

# %%
#把士東路299巷的經緯度取出來定義為loc，訂一個半徑變數叫rad
loc = geocode_result[0]['geometry']['location']
rad = 100
print(loc)
#用gmaps.places_radar這個代碼來查total有幾個結果
print("台北市士林區士東路299巷"+str(rad)+"公尺的餐廳數量: "+
str(len(gmaps.places_nearby(keyword="restaurant",location=loc, radius=rad)['results'])))
# Out:
# {'lat': 25.1105466, 'lng': 121.5255956}
# 台北市士林區士東路299巷100公尺的餐廳數量: 12

# %%
# 執行附近搜索
results = gmaps.places_nearby(
    location=loc,
    radius=100,
    keyword='restaurant',
    open_now=False,
    type='restaurant',
    language='zh-TW'
)

# 打印結果
for place in results['results']:
    print(place['name'])
# Out:
# 濟州館韓式料理 - 石鍋拌飯、韓式燒肉、銅盤烤肉、部隊鍋、包廂預約
# 夫妻檔客家料理‧私房
# 疆味燒烤
# 錢吟涮涮鍋
# 家鄉越南美食

# %%
results['results']
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 25.1106554, 'lng': 121.5254055},
#    'viewport': {'northeast': {'lat': 25.11200092989272,
#      'lng': 121.5268010298927},
#     'southwest': {'lat': 25.10930127010728, 'lng': 121.5241013701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': '濟州館韓式料理 - 石鍋拌飯、韓式燒肉、銅盤烤肉、部隊鍋、包廂預約',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1108,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117267352268005953024">Jessica Yu</a>'],
#     'photo_reference': 'AUc7tXUnUkgk5OtARmGe2-OgO2qF5-j-U9l_jvbl3hsU7YPFWYPjbGB7ONrBce965DsfbHdq1nwJe7rhaU3q41PfKYHXEsMwjIbJenpz-Jsmvz4DZ1JRfJQ3MeX481RNMixjqZHO3TB_7EFh4E-qX67mwTDr_NgWwefQZS0Z9yKEuEfS3beL',
#     'width': 1477}],
#   'place_id': 'ChIJV-dtboSuQjQRYYIUdjMjrV8',
#   'plus_code': {'compound_code': '4G6G+75 士林區 台北市',
#    'global_code': '7QQ34G6G+75'},
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'ChIJV-dtboSuQjQRYYIUdjMjrV8',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 371,
#   'vicinity': '中山北路六段299號1樓'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 25.1082379, 'lng': 121.5253685},
#    'viewport': {'northeast': {'lat': 25.10959852989272,
#      'lng': 121.5266479298927},
#     'southwest': {'lat': 25.10689887010728, 'lng': 121.5239482701072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': '夫妻檔客家料理‧私房',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106984925455336971186">Jacqueline Shen</a>'],
#     'photo_reference': 'AUc7tXVzdAwRF5lsbF47IBH7UsJbb9HSzDi-otaAB3YWWQAJq2QvjL1Tmm9bjhlyrAy9E0GxFJbakZJquegRkty0OJFzDbg05L9nxw3ox2KDQNYzyDacHISNfsFtNcEhZCa7eQT6x-GmoBetdDu7inJc8gke_g77cuvldIynHF_wpw683uGB',
#     'width': 4032}],
#   'place_id': 'ChIJCcU-dJCuQjQREObvBaoAEFQ',
#   'plus_code': {'compound_code': '4G5G+74 蘭雅里 台北市士林區',
#    'global_code': '7QQ34G5G+74'},
#   'rating': 4.7,
#   'reference': 'ChIJCcU-dJCuQjQREObvBaoAEFQ',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 67,
#   'vicinity': '中山北路六段204號2樓'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 25.1109487, 'lng': 121.5258123},
#    'viewport': {'northeast': {'lat': 25.11231632989272,
#      'lng': 121.5270988298927},
#     'southwest': {'lat': 25.10961667010728, 'lng': 121.5243991701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': '疆味燒烤',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2268,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114408970353946600822">Amour HSIEH</a>'],
#     'photo_reference': 'AUc7tXVfNjYDjwGHOVF8l8i3JQ0g-4yafPodG3x1T-LN7yOLhxTaLy2jiexov7h3XLsNNEG5oFowJ-n56jcYSmobuxEp3ulBRZmrYSOy89RxWTxsQDAY_wgGMARRKFLgLj5reDmNG1TcjULc5_yxtMMR7NKzrGDlIaRPRN7NqqCDwkUReG30',
#     'width': 4032}],
#   'place_id': 'ChIJL-hFXoWuQjQRDRLZzkDsJ9A',
#   'plus_code': {'compound_code': '4G6G+98 蘭雅里 台北市士林區',
#    'global_code': '7QQ34G6G+98'},
#   'rating': 4.2,
#   'reference': 'ChIJL-hFXoWuQjQRDRLZzkDsJ9A',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 90,
#   'vicinity': '中山北路六段314號'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 25.1104732, 'lng': 121.5253661},
#    'viewport': {'northeast': {'lat': 25.11181482989272,
#      'lng': 121.5267839298927},
#     'southwest': {'lat': 25.10911517010727, 'lng': 121.5240842701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': '錢吟涮涮鍋',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100361002725791505019">黃瑄</a>'],
#     'photo_reference': 'AUc7tXUAgoEpH30t2QmBYmABAX4YM54nSmRXFhQX-d4a9HLgK04bazX3NNrkR7KlcNNTIaJUkM-7jTHAHv6A9fgywPisrxB7i87_5y1MlPFHcLSOOj_tBYqjTO6VYPxJKIWg6Zb61F6F4Ja-kNm9vejpwKJZDM_tT7ZN36ldTLCywR6amI18',
#     'width': 4032}],
#   'place_id': 'ChIJtw-CuJyuQjQRU5XcTHe7CzU',
#   'plus_code': {'compound_code': '4G6G+55 蘭興里 台北市士林區',
#    'global_code': '7QQ34G6G+55'},
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'ChIJtw-CuJyuQjQRU5XcTHe7CzU',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 411,
#   'vicinity': '中山北路六段289號'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 25.1110164, 'lng': 121.5258321},
#    'viewport': {'northeast': {'lat': 25.11238157989272,
#      'lng': 121.5271178798927},
#     'southwest': {'lat': 25.10968192010727, 'lng': 121.5244182201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': '家鄉越南美食',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115251029286575962894">洪宥琪</a>'],
#     'photo_reference': 'AUc7tXXLfaZ_qELVOHsDoAEL4pRGo7R7xXOHYjlrvl6wfJIlFDJmtpZVIYPZjg6qWZaUhpoNoSWOVDJakmh4S23SXIR2hbVIFFWepTlxIjERkMiHIbEZY28OJIbydM05U2MAqYfDuGiHrGDsUijx0o5BndhZ-c4cUVtgIcIp1nN45uRzOQlD',
#     'width': 1920}],
#   'place_id': 'ChIJ698gXoWuQjQRH1nq9hEqnTg',
#   'plus_code': {'compound_code': '4G6G+C8 蘭雅里 台北市士林區',
#    'global_code': '7QQ34G6G+C8'},
#   'price_level': 1,
#   'rating': 4,
#   'reference': 'ChIJ698gXoWuQjQRH1nq9hEqnTg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 225,
#   'vicinity': '中山北路六段318號'}]

# %%
# 定義一個格式化電話號碼的函數
def format_phone_number(phone_number):
     # 去掉空格
    phone_number = phone_number.replace(" ", "")
    # 使用正則表達式匹配並格式化電話號碼
    match = re.match(r'^(\d{2})(\d{4})(\d{4})$', phone_number)
    if match:
        return f"{match.group(1)}-{match.group(2)}-{match.group(3)}"
    return phone_number

# %%
# 抓取每個餐廳的詳細資訊
for place in results['results']:
    place_id = place['place_id']
    # 獲取詳細信息
    place_details = gmaps.place(place_id=place_id, language='zh-TW')
    
    # 打印餐廳的相關信息
    name = place_details['result'].get('name')
    address = place_details['result'].get('formatted_address')
    phone_number = place_details['result'].get('formatted_phone_number')
    rating = place_details['result'].get('rating')
    user_ratings_total = place_details['result'].get('user_ratings_total')
    price_level = place_details['result'].get('price_level')
    website = place_details['result'].get('website')

    # 格式化電話號碼
    if phone_number:
        phone_number = format_phone_number(phone_number)
    
    
    
    print(f"名稱: {name}")
    print(f"地址: {address}")
    print(f"電話號碼: {phone_number}")
    print(f"評分: {rating} ({user_ratings_total} 則評論)")
    print(f"價位等級：{price_level}")
    print(f"網站: {website}")
    print("-" * 100)
# Out:
# 名稱: 濟州館韓式料理 - 石鍋拌飯、韓式燒肉、銅盤烤肉、部隊鍋、包廂預約
# 地址: 11155台灣台北市士林區中山北路六段299號1樓
# 電話號碼: 02-2832-8886
# 評分: 3.9 (371 則評論)
# 價位等級：2
# 網站: https://lin.ee/Hl33Px3
# ----------------------------------------------------------------------------------------------------
# 名稱: 夫妻檔客家料理‧私房
# 地址: 111台灣台北市士林區中山北路六段204號2樓
# 電話號碼: 09-3578-9201
# 評分: 4.7 (67 則評論)
# 價位等級：None
# 網站: None
# ----------------------------------------------------------------------------------------------------
# 名稱: 疆味燒烤
# 地址: 111台灣台北市士林區中山北路六段314號
# 電話號碼: 09-7858-7662
# 評分: 4.2 (90 則評論)
# 價位等級：None
# 網站: https://crystal25690.pixnet.net/blog/post/140196872
# ----------------------------------------------------------------------------------------------------
# 名稱: 錢吟涮涮鍋
# 地址: 111台灣台北市士林區中山北路六段289號
# 電話號碼: 02-2833-3725
# 評分: 3.9 (411 則評論)
# 價位等級：2
# 網站: None
# ----------------------------------------------------------------------------------------------------
# 名稱: 家鄉越南美食
# 地址: 111台灣台北市士林區中山北路六段318號
# 電話號碼: 02-2831-2682
# 評分: 4 (225 則評論)
# 價位等級：1
# 網站: None
# ----------------------------------------------------------------------------------------------------

# %%
# 定義一個格式化電話號碼的函數
def format_phone_number(phone_number):
    
    if phone_number is None:
        phone_number = "未提供電話號碼"
        return phone_number
    else:
        # 去掉空格
        phone_number = phone_number.replace(" ", "")
        # 使用正則表達式匹配並格式化電話號碼
        match = re.match(r'^(\d{2})(\d{4})(\d{4})$', phone_number)
        phone_number = f"{match.group(1)}-{match.group(2)}-{match.group(3)}"
    return phone_number
    
# 定義是否為None, 自設定為 “未提供”
def price_web(price_level, website):
    if price_level is None:
        price_level = "未提供價位範圍"
    elif price_level == 1:
        price_level = "300 以內"
    elif price_level == 2:
        price_level = "300 至 900"
    elif price_level == 3:
        price_level = "900 至 1,800"
    else:
        price_level = "超過 1800"

    if website is None:
        website = "此餐廳無網頁"

    return price_level, website


# 創建一個空的列表來存儲餐廳信息
restaurant_list = []

# 抓取每個餐廳的詳細資訊
for place in results['results']:
    place_id = place['place_id']
    # 獲取詳細信息
    place_details = gmaps.place(place_id=place_id, language='zh-TW')
    
    # 獲取餐廳的相關信息
    name = place_details['result'].get('name')
    address = place_details['result'].get('formatted_address')
    phone_number = place_details['result'].get('formatted_phone_number')
    rating = place_details['result'].get('rating')
    user_ratings_total = place_details['result'].get('user_ratings_total')
    price_level = place_details['result'].get('price_level')
    website = place_details['result'].get('website')
    


    # 格式化電話號碼
    phone_number = format_phone_number(phone_number)

    # 檢查是否為None, 自設定為 未提供
    price_level, website = price_web(price_level, website)
    
    # 創建一個字典來存儲餐廳的信息
    restaurant_info = {
        '名稱': name,
        '評分': rating,
        '評論數量': user_ratings_total,
        '價位範圍': price_level,
        '地址': address,
        '電話號碼': phone_number,
        '網站': website
    }
    
    # 將字典添加到列表中
    restaurant_list.append(restaurant_info)
  

# 美觀地打印餐廳列表
pprint(restaurant_list)
# Out:
# [{'價位範圍': '300 至 900',
#   '名稱': '濟州館韓式料理 - 石鍋拌飯、韓式燒肉、銅盤烤肉、部隊鍋、包廂預約',
#   '地址': '11155台灣台北市士林區中山北路六段299號1樓',
#   '網站': 'https://lin.ee/Hl33Px3',
#   '評分': 3.9,
#   '評論數量': 371,
#   '電話號碼': '02-2832-8886'},
#  {'價位範圍': '未提供價位範圍',
#   '名稱': '夫妻檔客家料理‧私房',
#   '地址': '111台灣台北市士林區中山北路六段204號2樓',
#   '網站': '此餐廳無網頁',
#   '評分': 4.7,
#   '評論數量': 67,
#   '電話號碼': '09-3578-9201'},
#  {'價位範圍': '未提供價位範圍',
#   '名稱': '疆味燒烤',
#   '地址': '111台灣台北市士林區中山北路六段314號',
#   '網站': 'https://crystal25690.pixnet.net/blog/post/140196872',
#   '評分': 4.2,
#   '評論數量': 90,
#   '電話號碼': '09-7858-7662'},
#  {'價位範圍': '300 至 900',
#   '名稱': '錢吟涮涮鍋',
#   '地址': '111台灣台北市士林區中山北路六段289號',
#   '網站': '此餐廳無網頁',
#   '評分': 3.9,
#   '評論數量': 411,
#   '電話號碼': '02-2833-3725'},
#  {'價位範圍': '300 以內',
#   '名稱': '家鄉越南美食',
#   '地址': '111台灣台北市士林區中山北路六段318號',
#   '網站': '此餐廳無網頁',
#   '評分': 4,
#   '評論數量': 225,
#   '電話號碼': '02-2831-2682'}]

# %%
print(len(restaurant_list))
# Out:
# 5

# %%
from random import choice

# 隨機抓一間餐廳顯示資料
random_restaurant = choice(restaurant_list)
for key, value in random_restaurant.items():
    print(f"{key}: {value}")
# Out:
# 名稱: 疆味燒烤
# 評分: 4.2
# 評論數量: 90
# 價位範圍: 未提供價位範圍
# 地址: 111台灣台北市士林區中山北路六段314號
# 電話號碼: 09-7858-7662
# 網站: https://crystal25690.pixnet.net/blog/post/140196872

# %%
import requests

def get_location_by_ip():
    response = requests.get('https://ipinfo.io/')
    data = response.json()
    location = data['loc'].split(',')
    latitude = float(location[0])
    longitude = float(location[1])
    return latitude, longitude

latitude, longitude = get_location_by_ip()

# 創建一個字典來存儲餐廳的信息
locip = {
    'lat': latitude,
    'lng': longitude,
}
print(locip)
# Out:
# {'lat': 25.0478, 'lng': 121.5319}

# %%
# 執行附近搜索
ip_results = gmaps.places_nearby(
    location=locip,
    radius=100,
    keyword='restaurant',
    open_now=True,
    type='restaurant',
    language='zh-TW'
)

# %%
for place in ip_results['results']:
    place_id = place['place_id']

# 獲取詳細信息
place_details = gmaps.place(place_id=place_id, language='zh-TW')
print(type(place_details))
pprint(place_details)
# Out:
# <class 'dict'>
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '88號',
#                                     'short_name': '88號',
#                                     'types': ['street_number']},
#                                    {'long_name': '新生北路一段',
#                                     'short_name': '新生北路一段',
#                                     'types': ['route']},
#                                    {'long_name': '正守里',
#                                     'short_name': '正守里',
#                                     'types': ['administrative_area_level_3',
#                                               'political']},
#                                    {'long_name': '中山區',
#                                     'short_name': '中山區',
#                                     'types': ['administrative_area_level_2',
#                                               'political']},
#                                    {'long_name': '台北市',
#                                     'short_name': '台北市',
#                                     'types': ['administrative_area_level_1',
#                                               'political']},
#                                    {'long_name': '台灣',
#                                     'short_name': 'TW',
#                                     'types': ['country', 'political']},
#                                    {'long_name': '10491',
#                                     'short_name': '10491',
#                                     'types': ['postal_code']}],
#             'adr_address': '<span class="postal-code">10491</span><span '
#                            'class="country-name">台灣</span><span '
#                            'class="region">台北市</span><span '
#                            'class="locality">中山區</span><span '
#                            'class="street-address">正守里新生北路一段88號</span>',
#             'business_status': 'OPERATIONAL',
#             'current_opening_hours': {'open_now': True,
#                                       'periods': [{'close': {'date': '2024-07-07',
#                                                              'day': 0,
#                                                              'time': '1500'},
#                                                    'open': {'date': '2024-07-07',
#                                                             'day': 0,
#                                                             'time': '1130'}},
#                                                   {'close': {'date': '2024-07-07',
#                                                              'day': 0,
#                                                              'time': '2200'},
#                                                    'open': {'date': '2024-07-07',
#                                                             'day': 0,
#                                                             'time': '1700'}},
#                                                   {'close': {'date': '2024-07-08',
#                                                              'day': 1,
#                                                              'time': '1500'},
#                                                    'open': {'date': '2024-07-08',
#                                                             'day': 1,
#                                                             'time': '1130'}},
#                                                   {'close': {'date': '2024-07-08',
#                                                              'day': 1,
#                                                              'time': '2200'},
#                                                    'open': {'date': '2024-07-08',
#                                                             'day': 1,
#                                                             'time': '1700'}},
#                                                   {'close': {'date': '2024-07-10',
#                                                              'day': 3,
#                                                              'time': '1500'},
#                                                    'open': {'date': '2024-07-10',
#                                                             'day': 3,
#                                                             'time': '1130'}},
#                                                   {'close': {'date': '2024-07-10',
#                                                              'day': 3,
#                                                              'time': '2200'},
#                                                    'open': {'date': '2024-07-10',
#                                                             'day': 3,
#                                                             'time': '1700'}},
#                                                   {'close': {'date': '2024-07-11',
#                                                              'day': 4,
#                                                              'time': '1500'},
#                                                    'open': {'date': '2024-07-11',
#                                                             'day': 4,
#                                                             'time': '1130'}},
#                                                   {'close': {'date': '2024-07-11',
#                                                              'day': 4,
#                                                              'time': '2200'},
#                                                    'open': {'date': '2024-07-11',
#                                                             'day': 4,
#                                                             'time': '1700'}},
#                                                   {'close': {'date': '2024-07-12',
#                                                              'day': 5,
#                                                              'time': '1500'},
#                                                    'open': {'date': '2024-07-12',
#                                                             'day': 5,
#                                                             'time': '1130'}},
#                                                   {'close': {'date': '2024-07-12',
#                                                              'day': 5,
#                                                              'time': '2200'},
#                                                    'open': {'date': '2024-07-12',
#                                                             'day': 5,
#                                                             'time': '1700'}},
#                                                   {'close': {'date': '2024-07-06',
#                                                              'day': 6,
#                                                              'time': '1500'},
#                                                    'open': {'date': '2024-07-06',
#                                                             'day': 6,
#                                                             'time': '1130'}},
#                                                   {'close': {'date': '2024-07-06',
#                                                              'day': 6,
#                                                              'time': '2200'},
#                                                    'open': {'date': '2024-07-06',
#                                                             'day': 6,
#                                                             'time': '1700'}}],
#                                       'weekday_text': ['星期一: 11:30 – 15:00, '
#                                                        '17:00 – 22:00',
#                                                        '星期二: 休息',
#                                                        '星期三: 11:30 – 15:00, '
#                                                        '17:00 – 22:00',
#                                                        '星期四: 11:30 – 15:00, '
#                                                        '17:00 – 22:00',
#                                                        '星期五: 11:30 – 15:00, '
#                                                        '17:00 – 22:00',
#                                                        '星期六: 11:30 – 15:00, '
#                                                        '17:00 – 22:00',
#                                                        '星期日: 11:30 – 15:00, '
#                                                        '17:00 – 22:00']},
#             'delivery': False,
#             'dine_in': True,
#             'editorial_summary': {'language': 'zh-TW',
#                                   'overview': '採用棒球主題裝潢的時髦餐廳，供應新英格蘭風味的龍蝦和牛排。'},
#             'formatted_address': '10491台灣台北市中山區新生北路一段88號',
#             'formatted_phone_number': '02 2541 9530',
#             'geometry': {'location': {'lat': 25.04774389999999,
#                                       'lng': 121.5297328},
#                          'viewport': {'northeast': {'lat': 25.0491226802915,
#                                                     'lng': 121.5311177302915},
#                                       'southwest': {'lat': 25.04642471970849,
#                                                     'lng': 121.5284197697085}}},
#             'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#             'icon_background_color': '#FF9E67',
#             'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#             'international_phone_number': '+886 2 2541 9530',
#             'name': 'Wayne’s Boston 瑋恩波士頓美式龍蝦牛排餐廳',
#             'opening_hours': {'open_now': True,
#                               'periods': [{'close': {'day': 0, 'time': '1500'},
#                                            'open': {'day': 0, 'time': '1130'}},
#                                           {'close': {'day': 0, 'time': '2200'},
#                                            'open': {'day': 0, 'time': '1700'}},
#                                           {'close': {'day': 1, 'time': '1500'},
#                                            'open': {'day': 1, 'time': '1130'}},
#                                           {'close': {'day': 1, 'time': '2200'},
#                                            'open': {'day': 1, 'time': '1700'}},
#                                           {'close': {'day': 3, 'time': '1500'},
#                                            'open': {'day': 3, 'time': '1130'}},
#                                           {'close': {'day': 3, 'time': '2200'},
#                                            'open': {'day': 3, 'time': '1700'}},
#                                           {'close': {'day': 4, 'time': '1500'},
#                                            'open': {'day': 4, 'time': '1130'}},
#                                           {'close': {'day': 4, 'time': '2200'},
#                                            'open': {'day': 4, 'time': '1700'}},
#                                           {'close': {'day': 5, 'time': '1500'},
#                                            'open': {'day': 5, 'time': '1130'}},
#                                           {'close': {'day': 5, 'time': '2200'},
#                                            'open': {'day': 5, 'time': '1700'}},
#                                           {'close': {'day': 6, 'time': '1500'},
#                                            'open': {'day': 6, 'time': '1130'}},
#                                           {'close': {'day': 6, 'time': '2200'},
#                                            'open': {'day': 6, 'time': '1700'}}],
#                               'weekday_text': ['星期一: 11:30 – 15:00, 17:00 – '
#                                                '22:00',
#                                                '星期二: 休息',
#                                                '星期三: 11:30 – 15:00, 17:00 – '
#                                                '22:00',
#                                                '星期四: 11:30 – 15:00, 17:00 – '
#                                                '22:00',
#                                                '星期五: 11:30 – 15:00, 17:00 – '
#                                                '22:00',
#                                                '星期六: 11:30 – 15:00, 17:00 – '
#                                                '22:00',
#                                                '星期日: 11:30 – 15:00, 17:00 – '
#                                                '22:00']},
#             'photos': [{'height': 1079,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/116023123925602639094">Wayne’s '
#                                               'Boston 瑋恩波士頓美式龍蝦牛排餐廳</a>'],
#                         'photo_reference': 'AUc7tXXX4gnzGzj8UUm5GrbxxUc8wNeBt17fWWF4lxvvZFUEMEbKQgGKu7f670XaNnaA8KiYByM4F7Xujg7ckEf3ksOycGxXfKTDwsq7JsI9yCK1fiUyhYUpDBXk9O3Z2flREbLXgs7f04gkUPgPgmXdcaZF_ItJtfcN1XmqCHS8GiCgorw',
#                         'width': 2048},
#                        {'height': 781,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/116023123925602639094">Wayne’s '
#                                               'Boston 瑋恩波士頓美式龍蝦牛排餐廳</a>'],
#                         'photo_reference': 'AUc7tXX0e-d-bBcWAry8wFMf-7n6i4hMYVjMZQ7wyX88OTtfjll516ePLlEJvxSmttz4qbUkM8XFU2VI16VbjzeUqSYn4Sa2OCdek7341f5x88ocPfUq7W6Iev9fJlMObLKGTsq4Vpegf7UszhIy0mQ-iYLRrTUqLKUmAGL-RmQP9IM13do',
#                         'width': 1044},
#                        {'height': 2894,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/117211857665936756850">Anita '
#                                               'Lee</a>'],
#                         'photo_reference': 'AUc7tXVs3hZ1tInbZpaAMWthxRcQP9aDe2s54C4V2UF_vBAUuShZGVUZ4wcVgqwMbCVeCbM5yBv8hbZzRrGGlW0opMEUX2eV0NI7uuYEtnA3ffBL77nNR50j51DWbuuRG5VIgoQRQi46fyLfDj49mT8d1qF-jjrgaXh_3V-YqGTlqctBVkC1',
#                         'width': 4080},
#                        {'height': 3000,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/104370431763031252244">黃柏瑋</a>'],
#                         'photo_reference': 'AUc7tXWYbMRe56Zb9OnSSX7ojOQDKXlLJaPZksRe2r2cCJyl1-evOElopTg7QvUVuKBnbAv7pHKDXDZxeA7UjobX_5XVWYlmtloYaDJ9RKzXIeCk8Wy2eucgKGmLl0MSiXbnv-ArutstSkTvjZzBP3zLhcg1d7zEPrDFviGqRqhbGUSnKBco',
#                         'width': 4000},
#                        {'height': 3044,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/117211857665936756850">Anita '
#                                               'Lee</a>'],
#                         'photo_reference': 'AUc7tXXsleNq4mCnlc2PMSg2ApWD9-bWD5-nW1H-lCqunIEL4tsOJbaB5BG6H62fwLq-7exXgbWuTJsXuknYm8IHHDWz8qRFc3gP5PkJj5_3QolJ1p56N_JzVhxl26hwsMAbILBXEWq8y143FJfGupeNJlJ9rACir-6iZ0sv9LWerkjHyAT5',
#                         'width': 4062},
#                        {'height': 3024,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/106720038100226951760">Nick '
#                                               'Lee</a>'],
#                         'photo_reference': 'AUc7tXWTWsW_eMEU0pfHRCTExBpuVLxbBjJBEbMnJ7ixxtoaPM16tMs0H4PpsS5eGqk8t_tDQXlQDCwLpgagR6bn-eeloTupwJFEiRASC6flOPzi5qPJDUkZvammc3Q_op7Nrfz00LVgl7eZB0HeqQjLRo8twcOscPA51wETRhZnHadEXTH0',
#                         'width': 4032},
#                        {'height': 2160,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/105124852144221459602">Win '
#                                               'Lee</a>'],
#                         'photo_reference': 'AUc7tXViBCiVc2BhlSSlfB3nFvwgsgL-4Lk5yYe7YHg2YomgD7VNTrRTqNA6AD6WcHGkjLoZuAQLdLhW7tiCaMljoLM0t0ADVJu-j1-2jQMmNjMwg6TnChka8aaC8-j3J4pM8M_jgVNETjcryVO4Q2k1ZMe7erM7Ug4aW771XPdDi66zNpY8',
#                         'width': 2160},
#                        {'height': 4096,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/105340913528198879253">楊允仁</a>'],
#                         'photo_reference': 'AUc7tXUZXpWP5th-EQrr5XV35MusMRR1VBW01aoGTsOW7U9qarJya7mMkpC4ioOHAmDrdihXgv8ykIqXKsvwhWWNyBr2cXl9UwxD6MRhrDsMmLxO989unFQai0vnYHwBt85GBA3TrR55G8DYXdV-gDNMVFcmIL9RYBpMIiysWgysvcBdPCMN',
#                         'width': 3072},
#                        {'height': 960,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/117939328951876189876">許心川</a>'],
#                         'photo_reference': 'AUc7tXW7FSavN3BLIeEWdjp9D4T6VTxE7-o8lYSRLAG7YL4i71gIEkA-zuphb_NeCxZFmNkOtGXw7MKAaqpk7mbKezm5msnCYXG7ep-j3g_iNIboz3yHSDuQU7S3mngjks7fToqRFKKF0wphQHFPY_BYpqSE5yRpoH4tKKLJtA2WWJKbI9V7',
#                         'width': 1139},
#                        {'height': 1171,
#                         'html_attributions': ['<a '
#                                               'href="https://maps.google.com/maps/contrib/108530319186258933431">Hsin '
#                                               'S</a>'],
#                         'photo_reference': 'AUc7tXUCz3Mq3r2wXrQic-wvLZ9Ui1jYulgx6MJUrEkVgeJjizY1mLRKKTInh2FjOj455nB69I6VrbWDMklYArZvlITX9fp7ut7BHptmW7BmQ1PNxnZ5qZmXO4yqcEqiL-Ug7UUab9g8lktnJBr2zgY-6ldAFDrdLHww8MBQn0tSe0AQRNjy',
#                         'width': 1216}],
#             'place_id': 'ChIJGfix9WSpQjQRt8-Hz1c_JCk',
#             'plus_code': {'compound_code': '2GXH+3V 台灣台北市中山區正守里',
#                           'global_code': '7QQ32GXH+3V'},
#             'price_level': 3,
#             'rating': 4.4,
#             'reference': 'ChIJGfix9WSpQjQRt8-Hz1c_JCk',
#             'reservable': True,
#             'reviews': [{'author_name': 'chang leon',
#                          'author_url': 'https://www.google.com/maps/contrib/107118307009432313257/reviews',
#                          'language': 'zh-Hant',
#                          'original_language': 'zh-Hant',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJ0As9w8gTZWz3jqFe5RMhH0W3gPRy0QxulkWybLgyDzefcWQ=s128-c0x00000000-cc-rp-mo-ba6',
#                          'rating': 5,
#                          'relative_time_description': '1 個月前',
#                          'text': '龍蝦+牛排雙人套餐$1950/人：附兩人份沙拉、黑麥麵包、湯、前菜、甜點！\n'
#                                  '\n'
#                                  '推薦濃郁經典波士頓龍蝦湯，可口鮮甜！\n'
#                                  '\n'
#                                  '🌟🌟火烤龍蝦肉有彈性、鮮美，配上黃油超享受！\n'
#                                  '\n'
#                                  '🌟🌟上蓋老饕肋眼牛排油脂豐厚，碳烤香氣十足，外皮微焦肉質軟嫩，搭配超柔滑奶油馬鈴薯泥！',
#                          'time': 1717576989,
#                          'translated': False},
#                         {'author_name': 'Shelly Liu',
#                          'author_url': 'https://www.google.com/maps/contrib/106209968162199143436/reviews',
#                          'language': 'zh-Hant',
#                          'original_language': 'zh-Hant',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjVcLc4KG2TZTYTUtTpGKm8SNvoNwB4gNmi2_AKLyK-EZ6SNFm3x=s128-c0x00000000-cc-rp-mo-ba5',
#                          'rating': 4,
#                          'relative_time_description': '2 個月前',
#                          'text': '我們兩人用餐點了雙龍蝦主餐，海鮮的部分都還蠻新鮮好吃的，搭配店內的老歌音樂，朋友覺得很有懷舊北美生活的感覺🤣\n'
#                                  '烤大蛤我們也很喜歡～\n'
#                                  '服務人員也會協助剝殼，這桌邊服務必須先給個讚👍🏻\n'
#                                  '相較於主菜，個人反而沒那麼喜歡配菜的部分，像是沙拉裡的火腿個人覺得有點太鹹，醬也稍多。黑麥蜂蜜麵包也真的偏普通，我們兩人只各吃了一片就請店員收走了。\n'
#                                  '差點忘了，杏仁霜也大贏布蕾，可惜我們兩個人的戰鬥力不足，不然很想把杏仁霜蛋糕吃完。',
#                          'time': 1714641195,
#                          'translated': False},
#                         {'author_name': 'CHICHI STAR',
#                          'author_url': 'https://www.google.com/maps/contrib/107523571340724430081/reviews',
#                          'language': 'zh-Hant',
#                          'original_language': 'zh-Hant',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a/ACg8ocJHaYbdIDkF2pzCcoPzyyeb88TmXXZZxbhFcLgY1lL4Jjr-7_E=s128-c0x00000000-cc-rp-mo',
#                          'rating': 5,
#                          'relative_time_description': '3 個月前',
#                          'text': '餐點真的非常好吃，龍蝦牛排都美味到極致，LEO很用心介紹食材，可以知道餐廳都是很用心準備，連沾牛排的鹽巴都用得很講究!!! '
#                                  '甜點的杏仁派真的是驚艷到我~不會太甜而且有冰淇淋的口感真的好好吃，價位是偏高，但偶爾去吃一次真的好滿足好幸福',
#                          'time': 1711899443,
#                          'translated': False},
#                         {'author_name': '楊允仁',
#                          'author_url': 'https://www.google.com/maps/contrib/105340913528198879253/reviews',
#                          'language': 'zh-Hant',
#                          'original_language': 'zh-Hant',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjWGi9oiy39F4HnQXmKt4WCagN132Ri15c58RUtDuNPBxfkZ8e8KJQ=s128-c0x00000000-cc-rp-mo-ba6',
#                          'rating': 4,
#                          'relative_time_description': '2 個月前',
#                          'text': '2024.05.01 '
#                                  '第一次來店用餐，整體來說還不錯，是一個適合聚餐或約會的地方，波龍很好吃，牛排如果太生還可以再調整熟度。',
#                          'time': 1714577782,
#                          'translated': False},
#                         {'author_name': 'ShiYu Wang',
#                          'author_url': 'https://www.google.com/maps/contrib/111849027512887775956/reviews',
#                          'language': 'zh-Hant',
#                          'original_language': 'zh-Hant',
#                          'profile_photo_url': 'https://lh3.googleusercontent.com/a-/ALV-UjW5UL_gEmkJaWDjeLTzK9D-0FgfBXnWSMPWIukWAmo-4JakZ9zY=s128-c0x00000000-cc-rp-mo-ba5',
#                          'rating': 5,
#                          'relative_time_description': '2 個月前',
#                          'text': '沙拉湯跟主菜甜點都很好吃！\n'
#                                  '沙拉不會很乾味道配合的不錯\n'
#                                  '湯是龍蝦湯跟松露湯各一\n'
#                                  '龍蝦湯跟松露湯味道都非常濃郁\n'
#                                  '前菜的厚培根很特別也好吃 不過吃多有點膩\n'
#                                  '龍蝦很新鮮 各種調味也很讚',
#                          'time': 1713273008,
#                          'translated': False}],
#             'serves_beer': True,
#             'serves_breakfast': False,
#             'serves_brunch': False,
#             'serves_dinner': True,
#             'serves_lunch': True,
#             'serves_wine': True,
#             'takeout': True,
#             'types': ['restaurant',
#                       'point_of_interest',
#                       'food',
#                       'establishment'],
#             'url': 'https://maps.google.com/?cid=2964564101093117879',
#             'user_ratings_total': 1268,
#             'utc_offset': 480,
#             'vicinity': '中山區新生北路一段88號',
#             'website': 'https://waynes.com.tw/'},
#  'status': 'OK'}

# %%
address = place_details['result']['formatted_address']
loc=place_details['result']['geometry']['location']
print(address)
print(loc)
print(locip)
# Out:
# 10491台灣台北市中山區新生北路一段88號
# {'lat': 25.04774389999999, 'lng': 121.5297328}
# {'lat': 25.0478, 'lng': 121.5319}

# %%
import json

# 抓台灣行政區資料
def twn_county():
    with open("countyname.json", "r") as countyfile:
        countyname_data = json.load(countyfile)

    for county in countyname_data['countyitems']['countyitem']:
        countname = county['countyname']
        print(countname)

twn_county()
# Out:
# 臺北市
# 臺中市
# 基隆市
# 臺南市
# 高雄市
# 新北市
# 宜蘭縣
# 桃園市
# 嘉義市
# 新竹縣
# 苗栗縣
# 南投縣
# 彰化縣
# 新竹市
# 雲林縣
# 嘉義縣
# 屏東縣
# 花蓮縣
# 臺東縣
# 金門縣
# 澎湖縣
# 連江縣
